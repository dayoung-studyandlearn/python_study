# %%
import pandas as pd
midwe=pd.read_csv('../../datasets/public/midwest.csv')
midwe
# Out:
#       PID     county state   area  ...  percadultpoverty  percelderlypoverty  inmetro  category
# 0     561      ADAMS    IL  0.052  ...         11.009776           12.443812        0       AAR
# 1     562  ALEXANDER    IL  0.014  ...         27.385647           25.228976        0       LHR
# 2     563       BOND    IL  0.022  ...         10.852090           12.697410        0       AAR
# 3     564      BOONE    IL  0.017  ...          5.536013            6.217047        1       ALU
# 4     565      BROWN    IL  0.018  ...         11.143211           19.200000        0       AAR
# ..    ...        ...   ...    ...  ...               ...                 ...      ...       ...
# 432  3048   WAUKESHA    WI  0.034  ...          2.590061            4.085479        1       HLU
# 433  3049    WAUPACA    WI  0.045  ...          6.953799           10.338641        0       AAR
# 434  3050   WAUSHARA    WI  0.037  ...         11.695784           11.804558        0       AAR
# ...

# %%
df=midwe.head()
df
# Out:
#    PID     county state   area  poptotal  ...  percchildbelowpovert  percadultpoverty  percelderlypoverty  inmetro  category
# 0  561      ADAMS    IL  0.052     66090  ...             18.011717         11.009776           12.443812        0       AAR
# 1  562  ALEXANDER    IL  0.014     10626  ...             45.826514         27.385647           25.228976        0       LHR
# 2  563       BOND    IL  0.022     14991  ...             14.036061         10.852090           12.697410        0       AAR
# 3  564      BOONE    IL  0.017     30806  ...             11.179536          5.536013            6.217047        1       ALU
# 4  565      BROWN    IL  0.018      5836  ...             13.022889         11.143211           19.200000        0       AAR
#
# [5 rows x 28 columns]

# %%
df.query('county=="ADAMS"|category=="AAR"')
# Out:
#    PID county state   area  poptotal  ...  percchildbelowpovert  percadultpoverty  percelderlypoverty  inmetro  category
# 0  561  ADAMS    IL  0.052     66090  ...             18.011717         11.009776           12.443812        0       AAR
# 2  563   BOND    IL  0.022     14991  ...             14.036061         10.852090           12.697410        0       AAR
# 4  565  BROWN    IL  0.018      5836  ...             13.022889         11.143211           19.200000        0       AAR
#
# [3 rows x 28 columns]

# %%
df.query("county=='ADAMS'&category=='AAR'")
# Out:
#    PID county state   area  poptotal  ...  percchildbelowpovert  percadultpoverty  percelderlypoverty  inmetro  category
# 0  561  ADAMS    IL  0.052     66090  ...             18.011717         11.009776           12.443812        0       AAR
#
# [1 rows x 28 columns]

# %%
var=13
df.query('percelderlypoverty>=@var')
# 위와 같이 @ 뒤에 변수를 넣어서 사용가능
# Out:
#    PID     county state   area  poptotal  ...  percchildbelowpovert  percadultpoverty  percelderlypoverty  inmetro  category
# 1  562  ALEXANDER    IL  0.014     10626  ...             45.826514         27.385647           25.228976        0       LHR
# 4  565      BROWN    IL  0.018      5836  ...             13.022889         11.143211           19.200000        0       AAR
#
# [2 rows x 28 columns]

# %%
# 데이터프레임 출력 제한 설정해제
pd.set_option('display.max_rows',None) # 행 출력제한 해제 설정
pd.set_option('display.max_columns',None) # 열 출력제한 해제 설정

# %%
midwe
# Out:
#       PID          county state   area  poptotal    popdensity  popwhite  \
# 0     561           ADAMS    IL  0.052     66090   1270.961540     63917
# 1     562       ALEXANDER    IL  0.014     10626    759.000000      7054
# 2     563            BOND    IL  0.022     14991    681.409091     14477
# 3     564           BOONE    IL  0.017     30806   1812.117650     29344
# 4     565           BROWN    IL  0.018      5836    324.222222      5264
# 5     566          BUREAU    IL  0.050     35688    713.760000     35157
# 6     567         CALHOUN    IL  0.017      5322    313.058824      5298
# 7     568         CARROLL    IL  0.027     16805    622.407407     16519
# 8     569            CASS    IL  0.024     13437    559.875000     13384
# 9     570       CHAMPAIGN    IL  0.058    173025   2983.189660    146506
# 10    571       CHRISTIAN    IL  0.042     34418    819.476190     34176
# 11    572           CLARK    IL  0.030     15921    530.700000     15842
# ...

# %%
# 설정 되돌리려면 새로운 커널을 사용하거나
pd.reset_option('display.max_columns')
pd.reset_option('display.max_rows')

pd.reset_option('all')
# Out:
# C:\Users\C\AppData\Local\Temp\ipykernel_23908\4014644199.py:5: FutureWarning: data_manager option is deprecated and will be removed in a future version. Only the BlockManager will be available.
#   pd.reset_option('all')
# C:\Users\C\AppData\Local\Temp\ipykernel_23908\4014644199.py:5: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   pd.reset_option('all')

# %%
mpg=pd.read_csv('../../datasets/public/mpg.csv')
mpg
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl category
# 0           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3           audi      a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..      ...
# 229   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p  midsize
# 230   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p  midsize
# 231   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p  midsize
# 232   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p  midsize
# 233   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p  midsize
#
# ...

# %%
displ4=mpg.query('displ<=4')

# %%
displ4['hwy'].mean()
# Out:
# np.float64(25.96319018404908)

# %%
displ5=mpg.query('displ>=5')

# %%
displ5['hwy'].mean()
# Out:
# np.float64(18.07894736842105)

# %%
mpg.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl category
# 0         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %%
audi=mpg.query('manufacturer=="audi"')
audi
# Out:
#    manufacturer       model  displ  year  cyl       trans drv  cty  hwy fl category
# 0          audi          a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 1          audi          a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 2          audi          a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 3          audi          a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 4          audi          a4    2.8  1999    6    auto(l5)   f   16   26  p  compact
# 5          audi          a4    2.8  1999    6  manual(m5)   f   18   26  p  compact
# 6          audi          a4    3.1  2008    6    auto(av)   f   18   27  p  compact
# 7          audi  a4 quattro    1.8  1999    4  manual(m5)   4   18   26  p  compact
# 8          audi  a4 quattro    1.8  1999    4    auto(l5)   4   16   25  p  compact
# 9          audi  a4 quattro    2.0  2008    4  manual(m6)   4   20   28  p  compact
# ...

# %%
toyota=mpg.query('manufacturer=="toyota"')
toyota
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  cty  hwy fl category
# 173       toyota             4runner 4wd    2.7  1999    4  manual(m5)   4   15   20  r      suv
# 174       toyota             4runner 4wd    2.7  1999    4    auto(l4)   4   16   20  r      suv
# 175       toyota             4runner 4wd    3.4  1999    6    auto(l4)   4   15   19  r      suv
# 176       toyota             4runner 4wd    3.4  1999    6  manual(m5)   4   15   17  r      suv
# 177       toyota             4runner 4wd    4.0  2008    6    auto(l5)   4   16   20  r      suv
# 178       toyota             4runner 4wd    4.7  2008    8    auto(l5)   4   14   17  r      suv
# 179       toyota                   camry    2.2  1999    4  manual(m5)   f   21   29  r  midsize
# 180       toyota                   camry    2.2  1999    4    auto(l4)   f   21   27  r  midsize
# 181       toyota                   camry    2.4  2008    4  manual(m5)   f   21   31  r  midsize
# ...

# %%
audi['cty'].mean()
# Out:
# np.float64(17.61111111111111)

# %%
toyota['cty'].mean()
# Out:
# np.float64(18.529411764705884)

# %%
# q3mean=mpg.query('manufacturer=="chevrolet"|manufacturer=="ford"|manufacturer=="honda"')
q3mean=mpg.query('manufacturer in ["chevrolet","ford","honda"]')
q3mean
# Out:
#     manufacturer               model  displ  year  cyl       trans drv  cty  hwy fl    category
# 18     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14   20  r         suv
# 19     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   11   15  e         suv
# 20     chevrolet  c1500 suburban 2wd    5.3  2008    8    auto(l4)   r   14   20  r         suv
# 21     chevrolet  c1500 suburban 2wd    5.7  1999    8    auto(l4)   r   13   17  r         suv
# 22     chevrolet  c1500 suburban 2wd    6.0  2008    8    auto(l4)   r   12   17  r         suv
# 23     chevrolet            corvette    5.7  1999    8  manual(m6)   r   16   26  p     2seater
# 24     chevrolet            corvette    5.7  1999    8    auto(l4)   r   15   23  p     2seater
# 25     chevrolet            corvette    6.2  2008    8  manual(m6)   r   16   26  p     2seater
# 26     chevrolet            corvette    6.2  2008    8    auto(s6)   r   15   25  p     2seater
# ...

# %%
q3mean['hwy'].mean()
# Out:
# np.float64(22.50943396226415)
